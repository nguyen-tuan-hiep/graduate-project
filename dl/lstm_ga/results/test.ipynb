# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv('results_sgd.csv')
df = pd.read_csv('./../../../ml/results/XGBRegressor_predictions.csv')
# df = pd.read_csv('./../../../ml/results/RandomForestRegressor_predictions.csv')
# df = pd.read_csv('./../../../ml/results/SVR_predictions.csv')
# df = pd.read_csv('./../../../ml/results/GradientBoostingRegressor_predictions.csv')

# %%
df
# Out:
#       Actual  Predicted
# 0      12.30  13.968068
# 1      12.20  13.076390
# 2      15.10  15.300272
# 3       6.10   5.193328
# 4      10.30  10.734563
# ...      ...        ...
# 3087    6.54   7.725282
# 3088    7.34   7.896272
# 3089    9.56  10.530827
# 3090   10.30  10.288499
# 3091   21.10  19.918339
#
# [3092 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(df['Actual'], df['Predicted'])
# Out:
# 0.88368311116295

# %%
def plot_results(y_true, y_pred):
    max_val = max(y_true.max(), y_pred.max())
    plt.figure(figsize=(5, 5))
    plt.plot([0, max_val], [0, max_val], color='black', linewidth=2, linestyle='-')
    sns.scatterplot(x=y_true, y=y_pred, color='red', alpha=0.5)
    plt.xlabel('Grount truth', fontsize=14)
    plt.ylabel('Predicted', fontsize=14)
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid()
    # plt.savefig('RandomForestRegressor_predictions.png')
    plt.savefig('XGBRegressor_predictions.pdf')
    plt.show()

# %%
plot_results(df['Actual'], df['Predicted'])
