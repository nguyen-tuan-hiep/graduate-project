# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./imputation_20.csv')

# %%
df['SDATE'] = pd.to_datetime(df['SDATE'])

# sort by date
df = df.sort_values(by='SDATE')
df.to_csv('imputation_20.csv', index=False)

# %%
df
# Out:
#             MC   STATID      SDATE     Y   M   D  TEMP_°C     pH  TSS_mg_L  \
# 0     Thailand  H310102 1985-07-15  1985   7  15     29.6  7.100   104.000
# 1     Thailand  H310102 1985-09-16  1985   9  16     28.5  6.900    43.000
# 2     Thailand  H050104 1985-10-15  1985  10  15     26.0  7.700    70.000
# 3     Thailand  H310102 1985-10-16  1985  10  16     28.0  7.240    40.000
# 4     Thailand  H310102 1985-11-12  1985  11  12     27.6  7.490     8.000
# ...        ...      ...        ...   ...  ..  ..      ...    ...       ...
# 4320  Thailand  H310102 2020-11-16  2020  11  16     30.0  6.450     3.167
# 4324  Thailand  H310102 2020-12-14  2020  12  14     27.0  7.110     8.167
# 4325  Thailand  H013801 2020-12-14  2020  12  14     25.0  7.985     8.917
# 4323  Thailand  H050104 2020-12-14  2020  12  14     22.0  7.555    21.417
# 4326  Thailand  H013101 2020-12-14  2020  12  14     25.0  7.760    30.000
#
# ...

# %%
df.columns
# Out:
# Index(['MC', 'STATID', 'SDATE', 'Y', 'M', 'D', 'TEMP_°C', 'pH', 'TSS_mg_L',
#        'COND_mS_m', 'Ca_meq_L', 'Mg_meq_L', 'Na_meq_L', 'K_meq_L', 'ALK_meq_L',
#        'Cl_meq_L', 'SO4_meq_L', 'NO32_mg_L', 'NH4N_mg_L', 'TOTP_mg_L',
#        'DO_mg_L', 'CODMN_mg_L'],
#       dtype='object')
